# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv('players_short.csv',names=['id','slug','url'])

# %%
df.head()
# Out:
#         id          slug                                                url
# 0  1076533    abdul-hadi  https://hs-consumer-api.espncricinfo.com/v1/pa...
# 1  1059030   abdul-malik  https://hs-consumer-api.espncricinfo.com/v1/pa...
# 2   524045  abdul-naseri  https://hs-consumer-api.espncricinfo.com/v1/pa...
# 3   819507  abdul-rahman  https://hs-consumer-api.espncricinfo.com/v1/pa...
# 4   974173    abdul-wasi  https://hs-consumer-api.espncricinfo.com/v1/pa...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9813 entries, 0 to 9812
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      9813 non-null   int64
#  1   slug    9813 non-null   object
#  2   url     9813 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 230.1+ KB

# %%
import concurrent.futures
import requests
import json
import time

# %%
players = []

# %%
def fetch_data(url):
    response = requests.get(url)
    if response.status_code ==200:
        data = json.loads(response.content)
        players.append(data)
        return data

# %%
start_time = time.time()
with concurrent.futures.ThreadPoolExecutor(max_workers=10) as executor:
    result = []
    result = list(executor.map(fetch_data,df['url'][:1000]))
    
end_time = time.time()
duration = end_time - start_time
print(f"total duration: {duration:.2f}")
# Out:
# total duration: 64.37

# %%
result[7]
# Out:
# {'player': {'id': 90409,
#   'objectId': 976467,
#   'name': 'Abdullah Naib',
#   'longName': 'Abdullah Naib',
#   'mobileName': '',
#   'indexName': 'Abdullah Naib',
#   'battingName': 'Abdullah Naib',
#   'fieldingName': 'Abdullah Naib',
#   'slug': 'abdullah-naib',
#   'imageUrl': None,
#   'dateOfBirth': {'year': 2001, 'month': 5, 'date': 31},
#   'dateOfDeath': None,
#   'gender': 'M',
#   'battingStyles': ['rhb'],
#   'bowlingStyles': ['ob'],
#   'longBattingStyles': ['right-hand bat'],
#   'longBowlingStyles': ['right-arm offbreak'],
#   'image': None,
#   'countryTeamId': 40,
#   'playerRoleTypeIds': [],
#   'playingRoles': [],
#   'headshotImage': None,
#   'fullName': 'Abdullah Naib',
#   'nickNames': '',
#   'alsoKnownAs': '',
#   'height': 0,
#   'heightUnit': None,
#   'education': '',
#   'country': {'id': 40,
#    'objectId': 40,
#    'name': 'Afghanistan',
#    'shortName': 'Afghanistan',
#    'abbreviation': 'AFG',
#    'slug': 'afghanistan',
#    'image': {'id': 321005,
#     'objectId': 1262396,
#     'slug': 'afghanistan-team-logo',
#     'url': '/db/PICTURES/CMS/321000/321005.png',
#     'width': 500,
#     'height': 500,
#     'caption': 'Afghanistan team logo',
#     'longCaption': 'Afghanistan team logo',
#     'credit': 'Unknown',
#     'photographer': None,
#     'peerUrls': None}},
#   'altCountryTeamId': None,
#   'placeOfBirth': '',
#   'dobText': None,
#   'dodText': None,
#   'placeOfDeath': '',
#   'intlCareerSpan': None,
#   'backgroundImage': None,
#   'externalLinks': [],
#   'fieldingStyles': [],
#   'otherStyles': [],
#   'matchPlayerTypes': [1],
#   'hasRecords': False,
#   'hasStats': True,
#   'hasMatches': True,
#   'totalStories': 0,
#   'totalVideos': 0,
#   'totalImages': 0},
#  'content': {'teams': [{'team': {'id': 4113,
#      'objectId': 228132,
#      'scribeId': 228132,
#      'slug': 'afghanistan-under-19s',
#      'name': 'Afghan U19',
#      'longName': 'Afghanistan Under-19s',
#      'abbreviation': 'AFG19',
#      'unofficialName': None,
#      'imageUrl': '/db/PICTURES/CMS/321000/321005.png',
#      'isCountry': False,
#      'primaryColor': None,
#      'image': {'id': 321005,
#       'objectId': 1262396,
#       'slug': 'afghanistan-team-logo',
#       'url': '/db/PICTURES/CMS/321000/321005.png',
#       'width': 500,
#       'height': 500,
#       'caption': 'Afghanistan team logo',
#       'longCaption': 'Afghanistan team logo',
#       'credit': 'Unknown',
#       'photographer': None,
#       'peerUrls': None}},
#     'current': False},
#    {'team': {'id': 5869,
#      'objectId': 973747,
#      'scribeId': 973747,
#      'slug': 'logar-province-under-17s',
#      'name': 'LogPro U17',
#      'longName': 'Logar Province Under-17s',
#      'abbreviation': 'LOU17',
#      'unofficialName': None,
#      'imageUrl': None,
#      'isCountry': False,
#      'primaryColor': None,
#      'image': None},
#     'current': False}],
#   'relations': [],
#   'profile': None,
#   'notes': None,
#   'nutshell': None,
#   'careerAverages': {'stats': []},
#   'topRecords': [],
#   'matches': {'types': [{'type': 1,
#      'matches': [],
#      'recent': [{'match': {'_uid': 94269,
#         'id': 94269,
#         'objectId': 1199147,
#         'scribeId': 1199147,
#         'slug': 'afghanistan-under-19s-vs-india-under-19s-9th-match-group-a',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': 15,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2019',
#         'title': '9th match, Group A',
#         'floodlit': 'day',
#         'startDate': '2019-09-09T00:00:00.000Z',
#         'endDate': '2019-09-09T00:00:00.000Z',
#         'startTime': '2019-09-09T04:30:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'India U19 won by 3 wickets (with 68 balls remaining)',
#         'statusEng': 'RESULT',
#         'internationalNumber': '001262',
#         'generalNumber': None,
#         'winnerTeamId': 1854,
#         'tossWinnerTeamId': 4113,
#         'tossWinnerChoice': 1,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 38.05,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 13299,
#          'objectId': 1199131,
#          'scribeId': 8616,
#          'slug': 'under-19s-asia-cup-2019',
#          'name': 'Under-19s Asia Cup',
#          'longName': 'Asian Cricket Council Under-19s Asia Cup',
#          'alternateName': 'U19 Asia Cup',
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2019,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Sri Lanka',
#          'season': '2019',
#          'startDate': '2019-09-05T00:00:00.000Z',
#          'endDate': '2019-09-14T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 339,
#          'objectId': 59294,
#          'name': 'Colombo Cricket Club Ground',
#          'smallName': 'Colombo (CCC)',
#          'longName': 'Colombo Cricket Club Ground',
#          'slug': 'colombo-cricket-club-ground',
#          'location': '',
#          'image': {'id': 31149,
#           'objectId': 59293,
#           'slug': 'portrait-of-colombo-cricket-club-ground-2001',
#           'url': '/db/PICTURES/DB/082001/029323.jpg',
#           'width': 547,
#           'height': 360,
#           'caption': 'Portrait of Colombo Cricket Club Ground, 2001',
#           'longCaption': 'Portrait of Colombo Cricket Club Ground, 2001',
#           'credit': 'ESPNcricinfo Ltd',
#           'photographer': 'Chinthaka Jayanath',
#           'peerUrls': None},
#          'town': {'id': 955,
#           'objectId': 59288,
#           'name': 'Colombo',
#           'area': '',
#           'timezone': 'Asia/Colombo'},
#          'country': {'id': 8,
#           'objectId': 8,
#           'name': 'Sri Lanka',
#           'shortName': 'Sri Lanka',
#           'abbreviation': 'SL',
#           'slug': 'sri-lanka'}},
#         'teams': [{'team': {'id': 4113,
#            'objectId': 228132,
#            'scribeId': 228132,
#            'slug': 'afghanistan-under-19s',
#            'name': 'Afghan U19',
#            'longName': 'Afghanistan Under-19s',
#            'abbreviation': 'AFG19',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/321000/321005.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 321005,
#             'objectId': 1262396,
#             'slug': 'afghanistan-team-logo',
#             'url': '/db/PICTURES/CMS/321000/321005.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'Afghanistan team logo',
#             'longCaption': 'Afghanistan team logo',
#             'credit': 'Unknown',
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': True,
#           'isLive': False,
#           'score': '124',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 1854,
#            'objectId': 1803,
#            'scribeId': 1803,
#            'slug': 'india-under-19s-young-cricketers',
#            'name': 'India U19',
#            'longName': 'India Under-19s',
#            'abbreviation': 'IND19',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313300/313308.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313308,
#             'objectId': 1241767,
#             'slug': 'india-under-19s-young-cricketers-logo',
#             'url': '/db/PICTURES/CMS/313300/313308.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'India Under-19s (Young Cricketers) logo',
#             'longCaption': 'India Under-19s (Young Cricketers) logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': False,
#           'isLive': False,
#           'score': '128/7',
#           'scoreInfo': '38.4/50 ov, T:125',
#           'inningNumbers': [2],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:29:37.040Z'},
#        'teamId': 4113,
#        'battingText': '1',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 84228,
#         'id': 84228,
#         'objectId': 1108887,
#         'scribeId': 1108887,
#         'slug': 'balkh-province-vs-logar-province-group-b',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2017',
#         'title': 'Group B',
#         'floodlit': 'day',
#         'startDate': '2017-07-17T00:00:00.000Z',
#         'endDate': '2017-07-17T00:00:00.000Z',
#         'startTime': '2017-07-17T04:45:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'Balkh won by 4 wickets (with 213 balls remaining)',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 5979,
#         'tossWinnerTeamId': 5979,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 14.03,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11912,
#          'objectId': 1108858,
#          'scribeId': 17912,
#          'slug': 'elite-cup-2017',
#          'name': 'Elite Cup',
#          'longName': 'Elite Cup Provincial Grade One Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Afghanistan',
#          'season': '2017',
#          'startDate': '2017-07-11T00:00:00.000Z',
#          'endDate': '2017-07-19T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 3299,
#          'objectId': 1013561,
#          'name': 'Speen Ghar Cricket Ground',
#          'smallName': 'Speen Ghar',
#          'longName': 'Speen Ghar Cricket Ground',
#          'slug': 'speen-ghar-cricket-ground',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6304,
#            'objectId': 1108867,
#            'scribeId': 1108867,
#            'slug': 'logar-province',
#            'name': 'Logar',
#            'longName': 'Logar Province',
#            'abbreviation': 'LOGAR',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '136',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 5979,
#            'objectId': 1013569,
#            'scribeId': 1013569,
#            'slug': 'balkh-province',
#            'name': 'Balkh',
#            'longName': 'Balkh Province',
#            'abbreviation': 'BALKH',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '137/6',
#           'scoreInfo': '14.3/50 ov, T:137',
#           'inningNumbers': [2],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:26:26.069Z'},
#        'teamId': 6304,
#        'battingText': '0',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 84223,
#         'id': 84223,
#         'objectId': 1108882,
#         'scribeId': 1108882,
#         'slug': 'kandahar-province-vs-logar-province-group-b',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 11,
#         'subClassId': None,
#         'season': '2017',
#         'title': 'Group B',
#         'floodlit': 'day',
#         'startDate': '2017-07-15T00:00:00.000Z',
#         'endDate': '2017-07-15T00:00:00.000Z',
#         'startTime': '2017-07-15T04:45:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'Logar won by 49 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 6304,
#         'tossWinnerTeamId': 5977,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 34.02,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11912,
#          'objectId': 1108858,
#          'scribeId': 17912,
#          'slug': 'elite-cup-2017',
#          'name': 'Elite Cup',
#          'longName': 'Elite Cup Provincial Grade One Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Afghanistan',
#          'season': '2017',
#          'startDate': '2017-07-11T00:00:00.000Z',
#          'endDate': '2017-07-19T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 2989,
#          'objectId': 789639,
#          'name': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'smallName': 'Amanullah',
#          'longName': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'slug': 'ghazi-amanullah-khan-international-cricket-stadium',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6304,
#            'objectId': 1108867,
#            'scribeId': 1108867,
#            'slug': 'logar-province',
#            'name': 'Logar',
#            'longName': 'Logar Province',
#            'abbreviation': 'LOGAR',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '229',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 5977,
#            'objectId': 1013567,
#            'scribeId': 1013567,
#            'slug': 'kandahar-province',
#            'name': 'Kandahar',
#            'longName': 'Kandahar Province',
#            'abbreviation': 'KDHAR',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '180',
#           'scoreInfo': 'T:230',
#           'inningNumbers': [2],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'MULTI',
#         'format': 'TEST',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:29:37.040Z'},
#        'teamId': 6304,
#        'battingText': '14',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 84216,
#         'id': 84216,
#         'objectId': 1108875,
#         'scribeId': 1108875,
#         'slug': 'paktia-province-vs-logar-province-group-b',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2017',
#         'title': 'Group B',
#         'floodlit': 'day',
#         'startDate': '2017-07-12T00:00:00.000Z',
#         'endDate': '2017-07-12T00:00:00.000Z',
#         'startTime': '2017-07-12T04:45:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'Paktia won by 23 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 5983,
#         'tossWinnerTeamId': 6304,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 49.01,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11912,
#          'objectId': 1108858,
#          'scribeId': 17912,
#          'slug': 'elite-cup-2017',
#          'name': 'Elite Cup',
#          'longName': 'Elite Cup Provincial Grade One Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Afghanistan',
#          'season': '2017',
#          'startDate': '2017-07-11T00:00:00.000Z',
#          'endDate': '2017-07-19T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 3299,
#          'objectId': 1013561,
#          'name': 'Speen Ghar Cricket Ground',
#          'smallName': 'Speen Ghar',
#          'longName': 'Speen Ghar Cricket Ground',
#          'slug': 'speen-ghar-cricket-ground',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 5983,
#            'objectId': 1013573,
#            'scribeId': 1013573,
#            'slug': 'paktia-province',
#            'name': 'Paktia',
#            'longName': 'Paktia Province',
#            'abbreviation': 'PKTIA',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '288',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 6304,
#            'objectId': 1108867,
#            'scribeId': 1108867,
#            'slug': 'logar-province',
#            'name': 'Logar',
#            'longName': 'Logar Province',
#            'abbreviation': 'LOGAR',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '265',
#           'scoreInfo': '49.1/50 ov, T:289',
#           'inningNumbers': [2],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:26:26.069Z'},
#        'teamId': 6304,
#        'battingText': '35',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 82457,
#         'id': 82457,
#         'objectId': 1076155,
#         'scribeId': 1076155,
#         'slug': 'baghlan-province-under-16s-vs-logar-province-under-16s-final',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 11,
#         'subClassId': None,
#         'season': '2016/17',
#         'title': 'Final',
#         'floodlit': 'day',
#         'startDate': '2017-01-30T00:00:00.000Z',
#         'endDate': '2017-01-30T00:00:00.000Z',
#         'startTime': '2017-01-30T03:30:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'LogPro U16 won by 4 wickets',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 6099,
#         'tossWinnerTeamId': 6099,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 20.03,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11676,
#          'objectId': 1076068,
#          'scribeId': 17920,
#          'slug': 'provincial-under-16s-2016-17',
#          'name': 'Provincial Under-16s',
#          'longName': 'Alokozay Provincial Under-16s Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 1,
#          'isTrophy': False,
#          'description': 'in Afghanistan',
#          'season': '2016/17',
#          'startDate': '2017-01-10T00:00:00.000Z',
#          'endDate': '2017-01-30T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 2989,
#          'objectId': 789639,
#          'name': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'smallName': 'Amanullah',
#          'longName': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'slug': 'ghazi-amanullah-khan-international-cricket-stadium',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6106,
#            'objectId': 1076108,
#            'scribeId': 1076108,
#            'slug': 'baghlan-province-under-16s',
#            'name': 'BagPro U16',
#            'longName': 'Baghlan Province Under-16s',
#            'abbreviation': 'BaU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '85',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 6099,
#            'objectId': 1076101,
#            'scribeId': 1076101,
#            'slug': 'logar-province-under-16s',
#            'name': 'LogPro U16',
#            'longName': 'Logar Province Under-16s',
#            'abbreviation': 'LOU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '86/6',
#           'scoreInfo': 'T:86',
#           'inningNumbers': [2],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'MULTI',
#         'format': 'TEST',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:29:37.040Z'},
#        'teamId': 6099,
#        'battingText': '28',
#        'bowlingText': '0/17',
#        'keepingText': None},
#       {'match': {'_uid': 82456,
#         'id': 82456,
#         'objectId': 1076154,
#         'scribeId': 1076154,
#         'slug': 'logar-province-under-16s-vs-paktika-province-under-16s-2nd-semi-final',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2016/17',
#         'title': '2nd Semi-final',
#         'floodlit': 'day',
#         'startDate': '2017-01-28T00:00:00.000Z',
#         'endDate': '2017-01-28T00:00:00.000Z',
#         'startTime': '2017-01-28T03:30:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'LogPro U16 won by 5 wickets (with 10 balls remaining) (D/L method)',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 6099,
#         'tossWinnerTeamId': 6099,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 27.02,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11676,
#          'objectId': 1076068,
#          'scribeId': 17920,
#          'slug': 'provincial-under-16s-2016-17',
#          'name': 'Provincial Under-16s',
#          'longName': 'Alokozay Provincial Under-16s Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 1,
#          'isTrophy': False,
#          'description': 'in Afghanistan',
#          'season': '2016/17',
#          'startDate': '2017-01-10T00:00:00.000Z',
#          'endDate': '2017-01-30T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 2989,
#          'objectId': 789639,
#          'name': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'smallName': 'Amanullah',
#          'longName': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'slug': 'ghazi-amanullah-khan-international-cricket-stadium',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6096,
#            'objectId': 1076098,
#            'scribeId': 1076098,
#            'slug': 'paktika-province-under-16s',
#            'name': 'PaktPro U16',
#            'longName': 'Paktika Province Under-16s',
#            'abbreviation': 'PKU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '117/9',
#           'scoreInfo': '29/29 ov',
#           'inningNumbers': [1],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 6099,
#            'objectId': 1076101,
#            'scribeId': 1076101,
#            'slug': 'logar-province-under-16s',
#            'name': 'LogPro U16',
#            'longName': 'Logar Province Under-16s',
#            'abbreviation': 'LOU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '104/5',
#           'scoreInfo': '27.2/29 ov, T:104',
#           'inningNumbers': [2],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:29:37.040Z'},
#        'teamId': 6099,
#        'battingText': '8',
#        'bowlingText': '4/19',
#        'keepingText': None},
#       {'match': {'_uid': 82442,
#         'id': 82442,
#         'objectId': 1076140,
#         'scribeId': 1076140,
#         'slug': 'logar-province-under-16s-vs-kapisa-province-under-16s-group-d',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2016/17',
#         'title': 'Group D',
#         'floodlit': 'day',
#         'startDate': '2017-01-22T00:00:00.000Z',
#         'endDate': '2017-01-22T00:00:00.000Z',
#         'startTime': '2017-01-22T05:00:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'LogPro U16 won by 8 wickets (with 113 balls remaining)',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 6099,
#         'tossWinnerTeamId': 6099,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 26.01,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11676,
#          'objectId': 1076068,
#          'scribeId': 17920,
#          'slug': 'provincial-under-16s-2016-17',
#          'name': 'Provincial Under-16s',
#          'longName': 'Alokozay Provincial Under-16s Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 1,
#          'isTrophy': False,
#          'description': 'in Afghanistan',
#          'season': '2016/17',
#          'startDate': '2017-01-10T00:00:00.000Z',
#          'endDate': '2017-01-30T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 2989,
#          'objectId': 789639,
#          'name': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'smallName': 'Amanullah',
#          'longName': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'slug': 'ghazi-amanullah-khan-international-cricket-stadium',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6101,
#            'objectId': 1076103,
#            'scribeId': 1076103,
#            'slug': 'kapisa-province-under-16s',
#            'name': 'KapPro U16',
#            'longName': 'Kapisa Province Under-16s',
#            'abbreviation': 'KPU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '135',
#           'scoreInfo': '41.1/45 ov',
#           'inningNumbers': [1],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 6099,
#            'objectId': 1076101,
#            'scribeId': 1076101,
#            'slug': 'logar-province-under-16s',
#            'name': 'LogPro U16',
#            'longName': 'Logar Province Under-16s',
#            'abbreviation': 'LOU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '139/2',
#           'scoreInfo': '26.1/45 ov, T:136',
#           'inningNumbers': [2],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:29:37.040Z'},
#        'teamId': 6099,
#        'battingText': None,
#        'bowlingText': '0/10',
#        'keepingText': None},
#       {'match': {'_uid': 82435,
#         'id': 82435,
#         'objectId': 1076133,
#         'scribeId': 1076133,
#         'slug': 'helmand-province-under-16s-vs-logar-province-under-16s-group-d',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2016/17',
#         'title': 'Group D',
#         'floodlit': 'day',
#         'startDate': '2017-01-19T00:00:00.000Z',
#         'endDate': '2017-01-19T00:00:00.000Z',
#         'startTime': '2017-01-19T05:00:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'LogPro U16 won by 78 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 6099,
#         'tossWinnerTeamId': 6102,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 33.01,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11676,
#          'objectId': 1076068,
#          'scribeId': 17920,
#          'slug': 'provincial-under-16s-2016-17',
#          'name': 'Provincial Under-16s',
#          'longName': 'Alokozay Provincial Under-16s Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 1,
#          'isTrophy': False,
#          'description': 'in Afghanistan',
#          'season': '2016/17',
#          'startDate': '2017-01-10T00:00:00.000Z',
#          'endDate': '2017-01-30T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 2989,
#          'objectId': 789639,
#          'name': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'smallName': 'Amanullah',
#          'longName': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'slug': 'ghazi-amanullah-khan-international-cricket-stadium',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6099,
#            'objectId': 1076101,
#            'scribeId': 1076101,
#            'slug': 'logar-province-under-16s',
#            'name': 'LogPro U16',
#            'longName': 'Logar Province Under-16s',
#            'abbreviation': 'LOU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '217',
#           'scoreInfo': '44.4/45 ov',
#           'inningNumbers': [1],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 6102,
#            'objectId': 1076104,
#            'scribeId': 1076104,
#            'slug': 'helmand-province-under-16s',
#            'name': 'HelPro U16',
#            'longName': 'Helmand Province Under-16s',
#            'abbreviation': 'HEU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '139',
#           'scoreInfo': '33.1/45 ov, T:218',
#           'inningNumbers': [2],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-14T21:29:37.040Z'},
#        'teamId': 6099,
#        'battingText': '28',
#        'bowlingText': '4/37',
#        'keepingText': None},
#       {'match': {'_uid': 82429,
#         'id': 82429,
#         'objectId': 1076127,
#         'scribeId': 1076127,
#         'slug': 'nangarhar-province-under-16s-vs-logar-province-under-16s-group-d',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '2016/17',
#         'title': 'Group D',
#         'floodlit': 'day',
#         'startDate': '2017-01-17T00:00:00.000Z',
#         'endDate': '2017-01-17T00:00:00.000Z',
#         'startTime': '2017-01-17T05:00:00.000Z',
#         'timePublished': True,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'Y',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'LogPro U16 won by 6 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 6099,
#         'tossWinnerTeamId': 6098,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': 48.03,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 11676,
#          'objectId': 1076068,
#          'scribeId': 17920,
#          'slug': 'provincial-under-16s-2016-17',
#          'name': 'Provincial Under-16s',
#          'longName': 'Alokozay Provincial Under-16s Tournament',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 2017,
#          'typeId': 1,
#          'isTrophy': False,
#          'description': 'in Afghanistan',
#          'season': '2016/17',
#          'startDate': '2017-01-10T00:00:00.000Z',
#          'endDate': '2017-01-30T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 2989,
#          'objectId': 789639,
#          'name': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'smallName': 'Amanullah',
#          'longName': 'Ghazi Amanullah Khan International Cricket Stadium',
#          'slug': 'ghazi-amanullah-khan-international-cricket-stadium',
#          'location': '',
#          'image': None,
#          'town': {'id': 1423,
#           'objectId': 789635,
#           'name': 'Amanullah',
#           'area': 'Nangarhar Province',
#           'timezone': 'Asia/Kabul'},
#          'country': {'id': 40,
#           'objectId': 40,
#           'name': 'Afghanistan',
#           'shortName': 'Afghanistan',
#           'abbreviation': 'AFG',
#           'slug': 'afghanistan'}},
#         'teams': [{'team': {'id': 6099,
#            'objectId': 1076101,
#            'scribeId': 1076101,
#            'slug': 'logar-province-under-16s',
#            'name': 'LogPro U16',
#            'longName': 'Logar Province Under-16s',
#            'abbreviation': 'LOU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': True,
#           'isLive': False,
#           'score': '222/9',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': 2,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 6098,
#            'objectId': 1076100,
#            'scribeId': 1076100,
#            'slug': 'nangarhar-province-under-16s',
#            'name': 'NanPro U16',
#            'longName': 'Nangarhar Province Under-16s',
#            'abbreviation': 'NaU16',
#            'unofficialName': None,
#            'imageUrl': None,
#            'isCountry': False,
#            'primaryColor': None,
#            'image': None},
#           'isHome': False,
#           'isLive': False,
#           'score': '216',
#           'scoreInfo': '48.3/50 ov, T:223',
#           'inningNumbers': [2],
#           'points': 0,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
# ...
#      'battingStyles': [],
#      'bowlingStyles': [],
#      'longBattingStyles': [],
#      'longBowlingStyles': [],
#      'image': {'id': 188227,
#       'objectId': 756531,
#       'slug': 'pakteen-umpire-portrait',
#       'url': '/db/PICTURES/CMS/188200/188227.1.jpg',
#       'width': 160,
#       'height': 165,
#       'caption': 'Pakteen umpire portrait',
#       'longCaption': 'Pakteen umpire portrait',
#       'credit': 'ESPNcricinfo Ltd',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [],
#      'playingRoles': [],
#      'headshotImage': None},
#     {'id': 98694,
#      'objectId': 1108490,
#      'name': 'Waqar Salamkheil',
#      'longName': 'Waqar Salamkheil',
#      'mobileName': 'Waqar',
#      'indexName': 'Waqar Salamkheil',
#      'battingName': 'Waqar Salamkheil',
#      'fieldingName': 'Waqar Salamkheil',
#      'slug': 'waqar-salamkheil',
#      'imageUrl': '/db/PICTURES/CMS/294300/294370.15.jpg',
#      'dateOfBirth': {'year': 2001, 'month': 10, 'date': 2},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lws'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['left-arm wrist-spin'],
#      'image': {'id': 294370,
#       'objectId': 1199619,
#       'slug': 'afghanistan-s-mystery-spinner-waqar-salamkheil',
#       'url': '/db/PICTURES/CMS/294300/294370.15.jpg',
#       'width': 160,
#       'height': 260,
#       'caption': "Afghanistan's mystery spinner Waqar Salamkheil",
#       'longCaption': "Afghanistan's mystery spinner Waqar Salamkheil",
#       'credit': '',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [4],
#      'playingRoles': ['bowler'],
#      'headshotImage': {'id': 326131,
#       'objectId': 1274390,
#       'slug': 'waqar-salamkheil-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/326100/326131.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Waqar Salamkheil, player page headshot cutout, 2021',
#       'longCaption': 'Waqar Salamkheil, player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/326100/326131.square.png'}}},
#     {'id': 79159,
#      'objectId': 793463,
#      'name': 'Rashid Khan',
#      'longName': 'Rashid Khan',
#      'mobileName': 'Rashid Khan',
#      'indexName': 'Rashid Khan',
#      'battingName': 'Rashid Khan',
#      'fieldingName': 'Rashid Khan',
#      'slug': 'rashid-khan',
#      'imageUrl': '/db/PICTURES/CMS/289200/289234.1.jpg',
#      'dateOfBirth': {'year': 1998, 'month': 9, 'date': 20},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lbg'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['legbreak googly'],
#      'image': {'id': 289234,
#       'objectId': 1184480,
#       'slug': 'rashid-khan-player-portrait',
#       'url': '/db/PICTURES/CMS/289200/289234.1.jpg',
#       'width': 160,
#       'height': 209,
#       'caption': 'Rashid Khan player portrait',
#       'longCaption': 'Rashid Khan player portrait',
#       'credit': 'Unknown',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [11],
#      'playingRoles': ['bowling allrounder'],
#      'headshotImage': {'id': 320506,
#       'objectId': 1261348,
#       'slug': 'rashid-khan-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/320500/320506.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Rashid Khan player page headshot cutout, 2021',
#       'longCaption': 'Rashid Khan player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/320500/320506.square.png'}}},
#     {'id': 46888,
#      'objectId': 25913,
#      'name': 'Mohammad Nabi',
#      'longName': 'Mohammad Nabi',
#      'mobileName': 'M Nabi',
#      'indexName': 'Mohammad Nabi',
#      'battingName': 'Mohammad Nabi',
#      'fieldingName': 'Mohammad Nabi',
#      'slug': 'mohammad-nabi',
#      'imageUrl': '/db/PICTURES/CMS/303200/303280.jpg',
#      'dateOfBirth': {'year': 1985, 'month': 1, 'date': 1},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['ob'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm offbreak'],
#      'image': {'id': 303280,
#       'objectId': 1221789,
#       'slug': 'mohammad-nabi-portrait',
#       'url': '/db/PICTURES/CMS/303200/303280.jpg',
#       'width': 160,
#       'height': 203,
#       'caption': 'Mohammad Nabi portrait',
#       'longCaption': 'Mohammad Nabi portrait, April 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [5],
#      'playingRoles': ['allrounder'],
#      'headshotImage': {'id': 316558,
#       'objectId': 1251187,
#       'slug': 'mohammad-nabi-headshot',
#       'url': '/db/PICTURES/CMS/316500/316558.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Mohammad Nabi headshot',
#       'longCaption': 'Mohammad Nabi headshot',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None, 'WIDE': None, 'SQUARE': None}}},
#     {'id': 67750,
#      'objectId': 568136,
#      'name': 'Fareed Ahmad',
#      'longName': 'Fareed Ahmad',
#      'mobileName': '',
#      'indexName': 'Fareed Ahmad',
#      'battingName': 'Fareed Ahmad',
#      'fieldingName': 'Fareed Ahmad',
#      'slug': 'fareed-ahmad',
#      'imageUrl': '/db/PICTURES/CMS/179000/179087.1.jpg',
#      'dateOfBirth': {'year': 1994, 'month': 8, 'date': 10},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['lfm'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['left-arm fast-medium'],
#      'image': {'id': 179087,
#       'objectId': 720033,
#       'slug': 'fareed-ahmad',
#       'url': '/db/PICTURES/CMS/179000/179087.1.jpg',
#       'width': 160,
#       'height': 192,
#       'caption': 'Fareed Ahmad',
#       'longCaption': 'Fareed Ahmad',
#       'credit': 'International Cricket Council',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [4],
#      'playingRoles': ['bowler'],
#      'headshotImage': {'id': 320494,
#       'objectId': 1261336,
#       'slug': 'fareed-ahmad-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/320400/320494.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Fareed Ahmad player page headshot cutout, 2021',
#       'longCaption': 'Fareed Ahmad player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/320400/320494.square.png'}}},
#     {'id': 57022,
#      'objectId': 352048,
#      'name': 'Gulbadin Naib',
#      'longName': 'Gulbadin Naib',
#      'mobileName': 'Gulbadin',
#      'indexName': 'Gulbadin Naib',
#      'battingName': 'Gulbadin Naib',
#      'fieldingName': 'Gulbadin Naib',
#      'slug': 'gulbadin-naib',
#      'imageUrl': '/db/PICTURES/CMS/303200/303268.jpg',
#      'dateOfBirth': {'year': 1991, 'month': 6, 'date': 4},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rmf'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium-fast'],
#      'image': {'id': 303268,
#       'objectId': 1221777,
#       'slug': 'gulbadin-naib-portrait',
#       'url': '/db/PICTURES/CMS/303200/303268.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'Gulbadin Naib portrait',
#       'longCaption': 'Gulbadin Naib portrait, April 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [10],
#      'playingRoles': ['batting allrounder'],
#      'headshotImage': {'id': 316661,
#       'objectId': 1251294,
#       'slug': 'gulbadin-naib-headshot',
#       'url': '/db/PICTURES/CMS/316600/316661.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Gulbadin Naib headshot',
#       'longCaption': 'Gulbadin Naib headshot',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None, 'WIDE': None, 'SQUARE': None}}},
#     {'id': 84865,
#      'objectId': 921509,
#      'name': 'Ibrahim Zadran',
#      'longName': 'Ibrahim Zadran',
#      'mobileName': '',
#      'indexName': 'Ibrahim Zadran',
#      'battingName': 'Ibrahim Zadran',
#      'fieldingName': 'Ibrahim Zadran',
#      'slug': 'ibrahim-zadran',
#      'imageUrl': '/db/PICTURES/CMS/303200/303273.jpg',
#      'dateOfBirth': {'year': 2001, 'month': 12, 'date': 12},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rmf'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium-fast'],
#      'image': {'id': 303273,
#       'objectId': 1221782,
#       'slug': 'ibrahim-zadran-portrait',
#       'url': '/db/PICTURES/CMS/303200/303273.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'Ibrahim Zadran portrait',
#       'longCaption': 'Ibrahim Zadran portrait, April 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [1],
#      'playingRoles': ['opening batter'],
#      'headshotImage': {'id': 321311,
#       'objectId': 1262884,
#       'slug': 'ibrahim-zadran-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/321300/321311.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Ibrahim Zadran player page headshot cutout, 2021',
#       'longCaption': 'Ibrahim Zadran player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/321300/321311.square.png'}}},
#     {'id': 61861,
#      'objectId': 440970,
#      'name': 'Hashmatullah Shahidi',
#      'longName': 'Hashmatullah Shahidi',
#      'mobileName': 'Hashmatullah',
#      'indexName': 'Hashmatullah Shahidi',
#      'battingName': 'Hashmatullah Shahidi',
#      'fieldingName': 'Hashmatullah Shahidi',
#      'slug': 'hashmatullah-shahidi',
#      'imageUrl': '/db/PICTURES/CMS/303200/303271.jpg',
#      'dateOfBirth': {'year': 1994, 'month': 11, 'date': 4},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['ob'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['right-arm offbreak'],
#      'image': {'id': 303271,
#       'objectId': 1221780,
#       'slug': 'hashmatullah-shahidi-portrait',
#       'url': '/db/PICTURES/CMS/303200/303271.jpg',
#       'width': 160,
#       'height': 201,
#       'caption': 'Hashmatullah Shahidi portrait',
#       'longCaption': 'Hashmatullah Shahidi portrait, April 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [2],
#      'playingRoles': ['top-order batter'],
#      'headshotImage': {'id': 320495,
#       'objectId': 1261337,
#       'slug': 'hashmatullah-shahidi-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/320400/320495.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Hashmatullah Shahidi player page headshot cutout, 2021',
#       'longCaption': 'Hashmatullah Shahidi player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/320400/320495.square.png'}}},
#     {'id': 90143,
#      'objectId': 974087,
#      'name': 'Rahmanullah Gurbaz',
#      'longName': 'Rahmanullah Gurbaz',
#      'mobileName': 'Gurbaz',
#      'indexName': 'Rahmanullah Gurbaz',
#      'battingName': 'Rahmanullah Gurbaz',
#      'fieldingName': 'Rahmanullah Gurbaz',
#      'slug': 'rahmanullah-gurbaz',
#      'imageUrl': '/db/PICTURES/CMS/357000/357020.1.png',
#      'dateOfBirth': {'year': 2001, 'month': 11, 'date': 28},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': [],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': [],
#      'image': {'id': 357020,
#       'objectId': 1365535,
#       'slug': 'rahmanullah-gurbaz-player-portrait',
#       'url': '/db/PICTURES/CMS/357000/357020.1.png',
#       'width': 160,
#       'height': 208,
#       'caption': 'Rahmanullah Gurbaz player portrait',
#       'longCaption': 'Rahmanullah Gurbaz player portrait',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [7],
#      'playingRoles': ['wicketkeeper batter'],
#      'headshotImage': {'id': 320504,
#       'objectId': 1261346,
#       'slug': 'rahmanullah-gurbaz-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/320500/320504.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Rahmanullah Gurbaz player page headshot cutout, 2021',
#       'longCaption': 'Rahmanullah Gurbaz player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/320500/320504.square.png'}}},
#     {'id': 79163,
#      'objectId': 793467,
#      'name': 'Karim Janat',
#      'longName': 'Karim Janat',
#      'mobileName': '',
#      'indexName': 'Karim Janat',
#      'battingName': 'Karim Janat',
#      'fieldingName': 'Karim Janat',
#      'slug': 'karim-janat',
#      'imageUrl': '/db/PICTURES/CMS/248200/248267.1.jpg',
#      'dateOfBirth': {'year': 1998, 'month': 8, 'date': 11},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rm'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium'],
#      'image': {'id': 248267,
#       'objectId': 1039759,
#       'slug': 'karim-janat-player-portrait',
#       'url': '/db/PICTURES/CMS/248200/248267.1.jpg',
#       'width': 160,
#       'height': 203,
#       'caption': 'Karim Janat player portrait',
#       'longCaption': 'Karim Janat player portrait',
#       'credit': 'ESPNcricinfo Ltd',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 40,
#      'playerRoleTypeIds': [11],
#      'playingRoles': ['bowling allrounder'],
#      'headshotImage': {'id': 320654,
#       'objectId': 1261554,
#       'slug': 'karim-janat-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/320600/320654.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Karim Janat player page headshot cutout, 2021',
#       'longCaption': 'Karim Janat player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/320600/320654.square.png'}}}],
#    'matchClassMetas': [{'id': 15,
#      'type': 'i',
#      'name': 'Youth One-Day Internationals'},
#     {'id': 11, 'type': 'g', 'name': 'Other matches'},
#     {'id': 12, 'type': 'g', 'name': 'Other one-day/limited-overs matches'}],
#    'recordClassMetas': [{'id': 14,
#      'type': 'g',
#      'name': 'Minor',
#      'longName': 'Minor cricket',
#      'multipleClass': 0,
#      'slug': 'minor-cricket'},
#     {'id': 21,
#      'type': 'i',
#      'name': 'Youth ODI',
#      'longName': 'Under-19s Youth One-Day Internationals',
#      'multipleClass': 0,
#      'slug': 'under-19s-youth-one-day-internationals'}],
#    'overallStats': [],
#    'teamFormatCapCounts': {'1': 27, '2': 58, '3': 51, '14': 11, '15': 121},
#    'teamContractedPlayerCount': 0,
#    'teamMatchClassMetas': [{'id': 1, 'type': 'i', 'name': 'Tests'},
#     {'id': 2, 'type': 'i', 'name': 'One-Day Internationals'},
#     {'id': 3, 'type': 'i', 'name': 'Twenty20 Internationals'},
#     {'id': 9, 'type': 'i', 'name': "Women's One-Day Internationals"},
#     {'id': 10, 'type': 'i', 'name': "Women's Twenty20 Internationals"},
#     {'id': 6, 'type': 'g', 'name': 'Twenty20'}]}}}

# %%
len(players)
# Out:
# 1100

# %%
players[1001]
# Out:
# {'player': {'id': 16707,
#   'objectId': 6798,
#   'name': 'BG Mitchell',
#   'longName': 'Brian Mitchell',
#   'mobileName': 'Mitchell',
#   'indexName': 'Mitchell, BG',
#   'battingName': 'BG Mitchell',
#   'fieldingName': 'Mitchell',
#   'slug': 'brian-mitchell',
#   'imageUrl': None,
#   'dateOfBirth': {'year': 1959, 'month': 3, 'date': 15},
#   'dateOfDeath': None,
#   'gender': 'M',
#   'battingStyles': ['rhb'],
#   'bowlingStyles': [],
#   'longBattingStyles': ['right-hand bat'],
#   'longBowlingStyles': [],
#   'image': None,
#   'countryTeamId': 2,
#   'playerRoleTypeIds': [],
#   'playingRoles': [],
#   'headshotImage': None,
#   'fullName': 'Brian Gordon Mitchell',
#   'nickNames': '',
#   'alsoKnownAs': '',
#   'height': None,
#   'heightUnit': None,
#   'education': None,
#   'country': {'id': 2,
#    'objectId': 2,
#    'name': 'Australia',
#    'shortName': 'Australia',
#    'abbreviation': 'AUS',
#    'slug': 'australia',
#    'image': {'id': 340493,
#     'objectId': 1318684,
#     'slug': 'australia-team-flag-latest',
#     'url': '/db/PICTURES/CMS/340400/340493.png',
#     'width': 500,
#     'height': 500,
#     'caption': 'Australia team flag-latest',
#     'longCaption': 'Australia team flag-latest',
#     'credit': 'Getty Images',
#     'photographer': None,
#     'peerUrls': None}},
#   'altCountryTeamId': None,
#   'placeOfBirth': 'Glenelg, Adelaide, South Australia',
#   'dobText': None,
#   'dodText': None,
#   'placeOfDeath': '',
#   'intlCareerSpan': None,
#   'backgroundImage': None,
#   'externalLinks': [],
#   'fieldingStyles': [],
#   'otherStyles': [],
#   'matchPlayerTypes': [1],
#   'hasRecords': False,
#   'hasStats': True,
#   'hasMatches': True,
#   'totalStories': 0,
#   'totalVideos': 0,
#   'totalImages': 0},
#  'content': {'teams': [{'team': {'id': 571,
#      'objectId': 520,
#      'scribeId': 520,
#      'slug': 'south-australia',
#      'name': 'South Aust',
#      'longName': 'South Australia',
#      'abbreviation': 'SOA',
#      'unofficialName': None,
#      'imageUrl': '/db/PICTURES/CMS/313200/313234.logo.png',
#      'isCountry': False,
#      'primaryColor': None,
#      'image': {'id': 313234,
#       'objectId': 1241693,
#       'slug': 'south-australia-logo',
#       'url': '/db/PICTURES/CMS/313200/313234.logo.png',
#       'width': 500,
#       'height': 500,
#       'caption': 'South Australia logo',
#       'longCaption': 'South Australia logo',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': None}},
#     'current': False}],
#   'relations': [],
#   'profile': None,
#   'notes': None,
#   'nutshell': None,
#   'careerAverages': {'stats': [{'type': 'BATTING',
#      'cl': 4,
#      'mt': 4,
#      'in': 6,
#      'rn': 92,
#      'bl': None,
#      'avg': 18.4,
#      'sr': None,
#      'no': 1,
#      'fo': None,
#      'si': None,
#      'hs': '23',
#      'hn': 0,
#      'ft': 0,
#      'ct': 5,
#      'st': 0},
#     {'type': 'BOWLING',
#      'cl': 4,
#      'mt': 4,
#      'in': None,
#      'rn': 0,
#      'bl': 0,
#      'avg': None,
#      'sr': None,
#      'wk': 0,
#      'bbi': '-',
#      'bbm': '-',
#      'fwk': 0,
#      'fw': 0,
#      'tw': 0,
#      'bwe': None}]},
#   'topRecords': [],
#   'matches': {'types': [{'type': 1,
#      'matches': [{'matchClass': {'id': 4, 'name': 'First-class', 'type': 'g'},
#        'total': 4,
#        'events': [{'interval': 'SPAN',
#          'match': None,
#          'span': '1978/79 - 1978/79'}]}],
#      'recent': [{'match': {'_uid': 19551,
#         'id': 19551,
#         'objectId': 357299,
#         'scribeId': 357299,
#         'slug': 'western-australia-vs-south-australia',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 4,
#         'subClassId': None,
#         'season': '1978/79',
#         'title': '',
#         'floodlit': 'day',
#         'startDate': '1979-03-03T00:00:00.000Z',
#         'endDate': '1979-03-05T00:00:00.000Z',
#         'startTime': '1979-03-03T02:30:00.000Z',
#         'timePublished': False,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'N',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'West Aust won by an innings and 41 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 653,
#         'tossWinnerTeamId': None,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 3,
#         'liveInningPredictions': None,
#         'liveOvers': None,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 4419,
#          'objectId': 356348,
#          'scribeId': 8043,
#          'slug': 'sheffield-shield-1978-79',
#          'name': 'Sheffield Shield',
#          'longName': 'Sheffield Shield',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 1978,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Australia',
#          'season': '1978/79',
#          'startDate': '1978-11-03T00:00:00.000Z',
#          'endDate': '1979-03-05T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 213,
#          'objectId': 56490,
#          'name': 'Western Australia Cricket Association Ground, Perth',
#          'smallName': 'Perth',
#          'longName': 'Western Australia Cricket Association Ground, Perth',
#          'slug': 'w-a-c-a-ground-perth',
#          'location': 'East Perth',
#          'image': {'id': 40407,
#           'objectId': 56489,
#           'slug': 'test-cricket-under-lights',
#           'url': '/db/PICTURES/DB/111997/000226.jpg',
#           'width': 390,
#           'height': 245,
#           'caption': 'Test cricket under lights',
#           'longCaption': 'Shane Warne bowls the first Test match ball under lights. Australia v New Zealand 2nd Test, Day One, at the WACA, Perth, Thursday November 20th 1997',
#           'credit': 'Action Photographics',
#           'photographer': 'Colin Whelan',
#           'peerUrls': None},
#          'town': {'id': 27,
#           'objectId': 56486,
#           'name': 'Perth',
#           'area': 'Western Australia',
#           'timezone': 'Australia/Perth'},
#          'country': {'id': 2,
#           'objectId': 2,
#           'name': 'Australia',
#           'shortName': 'Australia',
#           'abbreviation': 'AUS',
#           'slug': 'australia'}},
#         'teams': [{'team': {'id': 571,
#            'objectId': 520,
#            'scribeId': 520,
#            'slug': 'south-australia',
#            'name': 'South Aust',
#            'longName': 'South Australia',
#            'abbreviation': 'SOA',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313234.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313234,
#             'objectId': 1241693,
#             'slug': 'south-australia-logo',
#             'url': '/db/PICTURES/CMS/313200/313234.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'South Australia logo',
#             'longCaption': 'South Australia logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': True,
#           'isLive': False,
#           'score': '107 & 145',
#           'scoreInfo': None,
#           'inningNumbers': [1, 3],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 653,
#            'objectId': 602,
#            'scribeId': 602,
#            'slug': 'western-australia',
#            'name': 'West Aust',
#            'longName': 'Western Australia',
#            'abbreviation': 'WA',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313237.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313237,
#             'objectId': 1241696,
#             'slug': 'western-australia-logo',
#             'url': '/db/PICTURES/CMS/313200/313237.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'Western Australia logo',
#             'longCaption': 'Western Australia logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': False,
#           'isLive': False,
#           'score': '293',
#           'scoreInfo': None,
#           'inningNumbers': [2],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'MULTI',
#         'format': 'TEST',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-13T23:09:07.845Z'},
#        'teamId': 571,
#        'battingText': '9 & 14',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 19549,
#         'id': 19549,
#         'objectId': 357297,
#         'scribeId': 357297,
#         'slug': 'south-australia-vs-queensland',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 4,
#         'subClassId': None,
#         'season': '1978/79',
#         'title': '',
#         'floodlit': 'day',
#         'startDate': '1979-02-24T00:00:00.000Z',
#         'endDate': '1979-02-26T00:00:00.000Z',
#         'startTime': '1979-02-24T00:30:00.000Z',
#         'timePublished': False,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'N',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'South Aust won by 9 wickets',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': 571,
#         'tossWinnerTeamId': None,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 4,
#         'liveInningPredictions': None,
#         'liveOvers': None,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 4419,
#          'objectId': 356348,
#          'scribeId': 8043,
#          'slug': 'sheffield-shield-1978-79',
#          'name': 'Sheffield Shield',
#          'longName': 'Sheffield Shield',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 1978,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Australia',
#          'season': '1978/79',
#          'startDate': '1978-11-03T00:00:00.000Z',
#          'endDate': '1979-03-05T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 131,
#          'objectId': 56293,
#          'name': 'Adelaide Oval',
#          'smallName': 'Adelaide',
#          'longName': 'Adelaide Oval',
#          'slug': 'adelaide-oval',
#          'location': 'North Adelaide',
#          'image': {'id': 173155,
#           'objectId': 695353,
#           'slug': 'a-general-view-of-the-adelaide-oval',
#           'url': '/db/PICTURES/CMS/173100/173155.jpg',
#           'width': 900,
#           'height': 600,
#           'caption': 'A general view of the Adelaide Oval',
#           'longCaption': 'A general view of the Adelaide Oval, South Australia v Tasmania, Sheffield Shield, 3rd day, Adelaide, November 24, 2013',
#           'credit': 'Getty Images',
#           'photographer': None,
#           'peerUrls': None},
#          'town': {'id': 2,
#           'objectId': 56292,
#           'name': 'Adelaide',
#           'area': 'South Australia',
#           'timezone': 'Australia/Adelaide'},
#          'country': {'id': 2,
#           'objectId': 2,
#           'name': 'Australia',
#           'shortName': 'Australia',
#           'abbreviation': 'AUS',
#           'slug': 'australia'}},
#         'teams': [{'team': {'id': 510,
#            'objectId': 459,
#            'scribeId': 459,
#            'slug': 'queensland',
#            'name': 'Queensland',
#            'longName': 'Queensland',
#            'abbreviation': 'QLD',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313233.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313233,
#             'objectId': 1241692,
#             'slug': 'queensland-logo',
#             'url': '/db/PICTURES/CMS/313200/313233.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'Queensland logo',
#             'longCaption': 'Queensland logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': True,
#           'isLive': False,
#           'score': '155 & 127',
#           'scoreInfo': None,
#           'inningNumbers': [1, 3],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 571,
#            'objectId': 520,
#            'scribeId': 520,
#            'slug': 'south-australia',
#            'name': 'South Aust',
#            'longName': 'South Australia',
#            'abbreviation': 'SOA',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313234.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313234,
#             'objectId': 1241693,
#             'slug': 'south-australia-logo',
#             'url': '/db/PICTURES/CMS/313200/313234.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'South Australia logo',
#             'longCaption': 'South Australia logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': False,
#           'isLive': False,
#           'score': '200 & 85/1',
#           'scoreInfo': 'T:83',
#           'inningNumbers': [2, 4],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'MULTI',
#         'format': 'TEST',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-13T23:09:01.628Z'},
#        'teamId': 571,
#        'battingText': '21',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 19545,
#         'id': 19545,
#         'objectId': 357293,
#         'scribeId': 357293,
#         'slug': 'new-south-wales-vs-south-australia',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': None,
#         'generalClassId': 4,
#         'subClassId': None,
#         'season': '1978/79',
#         'title': '',
#         'floodlit': 'day',
#         'startDate': '1979-02-17T00:00:00.000Z',
#         'endDate': '1979-02-20T00:00:00.000Z',
#         'startTime': '1979-02-17T00:00:00.000Z',
#         'timePublished': False,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'N',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'Match drawn',
#         'statusEng': 'RESULT',
#         'internationalNumber': None,
#         'generalNumber': None,
#         'winnerTeamId': None,
#         'tossWinnerTeamId': None,
#         'tossWinnerChoice': 2,
#         'resultStatus': 4,
#         'liveInning': 4,
#         'liveInningPredictions': None,
#         'liveOvers': None,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 4419,
#          'objectId': 356348,
#          'scribeId': 8043,
#          'slug': 'sheffield-shield-1978-79',
#          'name': 'Sheffield Shield',
#          'longName': 'Sheffield Shield',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 1978,
#          'typeId': 3,
#          'isTrophy': True,
#          'description': 'in Australia',
#          'season': '1978/79',
#          'startDate': '1978-11-03T00:00:00.000Z',
#          'endDate': '1979-03-05T00:00:00.000Z',
#          'hasStandings': True,
#          'standingsType': 2,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 132,
#          'objectId': 56544,
#          'name': 'Sydney Cricket Ground',
#          'smallName': 'Sydney',
#          'longName': 'Sydney Cricket Ground',
#          'slug': 'sydney-cricket-ground',
#          'location': 'Moore Park',
#          'image': {'id': 516,
#           'objectId': 56543,
#           'slug': 'sydney-cricket-ground',
#           'url': '/db/PICTURES/DB/011999/003928.jpg',
#           'width': 450,
#           'height': 275,
#           'caption': 'Sydney Cricket Ground',
#           'longCaption': 'Sydney Cricket Ground',
#           'credit': 'Action Photographics',
#           'photographer': None,
#           'peerUrls': None},
#          'town': {'id': 29,
#           'objectId': 56531,
#           'name': 'Sydney',
#           'area': 'New South Wales',
#           'timezone': 'Australia/Sydney'},
#          'country': {'id': 2,
#           'objectId': 2,
#           'name': 'Australia',
#           'shortName': 'Australia',
#           'abbreviation': 'AUS',
#           'slug': 'australia'}},
#         'teams': [{'team': {'id': 571,
#            'objectId': 520,
#            'scribeId': 520,
#            'slug': 'south-australia',
#            'name': 'South Aust',
#            'longName': 'South Australia',
#            'abbreviation': 'SOA',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313234.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313234,
#             'objectId': 1241693,
#             'slug': 'south-australia-logo',
#             'url': '/db/PICTURES/CMS/313200/313234.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'South Australia logo',
#             'longCaption': 'South Australia logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': True,
#           'isLive': False,
#           'score': '376 & 196/2d',
#           'scoreInfo': None,
#           'inningNumbers': [1, 3],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 438,
#            'objectId': 387,
#            'scribeId': 387,
#            'slug': 'new-south-wales',
#            'name': 'NSW',
#            'longName': 'New South Wales',
#            'abbreviation': 'NSW',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/349300/349350.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 349350,
#             'objectId': 1345238,
#             'slug': 'new-south-wales-team-logo-2022',
#             'url': '/db/PICTURES/CMS/349300/349350.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'New South Wales Team logo (2022)',
#             'longCaption': 'New South Wales Team logo (2022)',
#             'credit': 'New South Wales Cricket Association',
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': False,
#           'isLive': False,
#           'score': '304 & 163/4',
#           'scoreInfo': 'T:269',
#           'inningNumbers': [2, 4],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'MULTI',
#         'format': 'TEST',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-13T23:09:07.845Z'},
#        'teamId': 571,
#        'battingText': '19 & 6*',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 16417,
#         'id': 16417,
#         'objectId': 323802,
#         'scribeId': 323802,
#         'slug': 'england-young-cricketers-vs-australia-young-cricketers-2nd-odi',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': 15,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '1977',
#         'title': '2nd ODI',
#         'floodlit': 'day',
#         'startDate': '1977-07-11T00:00:00.000Z',
#         'endDate': '1977-07-11T00:00:00.000Z',
#         'startTime': '1977-07-11T10:00:00.000Z',
#         'timePublished': False,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'N',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'Australia YC won by 40 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': '000003',
#         'generalNumber': None,
#         'winnerTeamId': 284,
#         'tossWinnerTeamId': None,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': None,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 3674,
#          'objectId': 323793,
#          'scribeId': 17144,
#          'slug': 'australia-young-cricketers-tour-of-england-1977',
#          'name': 'Australia Young Cricketers tour of England',
#          'longName': 'Australia Young Cricketers tour of England',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 1977,
#          'typeId': 4,
#          'isTrophy': False,
#          'description': '',
#          'season': '1977',
#          'startDate': '1977-07-09T00:00:00.000Z',
#          'endDate': '1977-07-11T00:00:00.000Z',
#          'hasStandings': False,
#          'standingsType': 1,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 10,
#          'objectId': 57129,
#          'name': "Lord's, London",
#          'smallName': "Lord's",
#          'longName': "Lord's, London",
#          'slug': 'lord-s-london',
#          'location': "St John's Wood Road",
#          'image': {'id': 92191,
#           'objectId': 360855,
#           'slug': 'a-wide-angle-view-of-lord-s',
#           'url': '/db/PICTURES/CMS/92100/92191.jpg',
#           'width': 500,
#           'height': 331,
#           'caption': "A wide-angle view of Lord's",
#           'longCaption': "A wide-angle view of Lord's, England v South Africa, 1st Test, Lord's, 3rd day, July 12, 2008",
#           'credit': 'Getty Images',
#           'photographer': None,
#           'peerUrls': None},
#          'town': {'id': 224,
#           'objectId': 57124,
#           'name': 'London',
#           'area': '',
#           'timezone': 'Europe/London'},
#          'country': {'id': 1,
#           'objectId': 1,
#           'name': 'England',
#           'shortName': 'England',
#           'abbreviation': 'ENG',
#           'slug': 'england'}},
#         'teams': [{'team': {'id': 284,
#            'objectId': 233,
#            'scribeId': 233,
#            'slug': 'australia-under-19s',
#            'name': 'Australia YC',
#            'longName': 'Australia Young Cricketers',
#            'abbreviation': 'AusYC',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313224.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313224,
#             'objectId': 1241683,
#             'slug': 'australia-under-19s-logo',
#             'url': '/db/PICTURES/CMS/313200/313224.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'Australia Under-19s logo',
#             'longCaption': 'Australia Under-19s logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': True,
#           'isLive': False,
#           'score': '249/8',
#           'scoreInfo': None,
#           'inningNumbers': [1],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 1022,
#            'objectId': 971,
#            'scribeId': 971,
#            'slug': 'england-under-19s-young-cricketers',
#            'name': 'England YC',
#            'longName': 'England Young Cricketers',
#            'abbreviation': 'EngYC',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313260.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313260,
#             'objectId': 1241719,
#             'slug': 'england-under-19s-young-cricketers-logo',
#             'url': '/db/PICTURES/CMS/313200/313260.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'England Under-19s (Young Cricketers) logo',
#             'longCaption': 'England Under-19s (Young Cricketers) logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': False,
#           'isLive': False,
#           'score': '209',
#           'scoreInfo': '49.4/55 ov, T:250',
#           'inningNumbers': [2],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-13T23:05:54.713Z'},
#        'teamId': 284,
#        'battingText': '22',
#        'bowlingText': None,
#        'keepingText': None},
#       {'match': {'_uid': 16416,
#         'id': 16416,
#         'objectId': 323801,
#         'scribeId': 323801,
#         'slug': 'england-young-cricketers-vs-australia-young-cricketers-1st-odi',
#         'stage': 'FINISHED',
#         'state': 'POST',
#         'internationalClassId': 15,
#         'generalClassId': 12,
#         'subClassId': None,
#         'season': '1977',
#         'title': '1st ODI',
#         'floodlit': 'day',
#         'startDate': '1977-07-09T00:00:00.000Z',
#         'endDate': '1977-07-09T00:00:00.000Z',
#         'startTime': '1977-07-09T10:00:00.000Z',
#         'timePublished': False,
#         'scheduleNote': '',
#         'isCancelled': False,
#         'coverage': 'N',
#         'coverageNote': '',
#         'liveStreamUrl': None,
#         'countryLiveStreamUrl': {},
#         'highlightsUrl': None,
#         'countryHighlightsUrl': {},
#         'status': 'RESULT',
#         'statusText': 'England YC won by 32 runs',
#         'statusEng': 'RESULT',
#         'internationalNumber': '000002',
#         'generalNumber': None,
#         'winnerTeamId': 1022,
#         'tossWinnerTeamId': None,
#         'tossWinnerChoice': 2,
#         'resultStatus': 1,
#         'liveInning': 2,
#         'liveInningPredictions': None,
#         'liveOvers': None,
#         'liveOversPending': None,
#         'liveBalls': None,
#         'liveRecentBalls': None,
#         'livePlayers': None,
#         'ballsPerOver': None,
#         'series': {'id': 3674,
#          'objectId': 323793,
#          'scribeId': 17144,
#          'slug': 'australia-young-cricketers-tour-of-england-1977',
#          'name': 'Australia Young Cricketers tour of England',
#          'longName': 'Australia Young Cricketers tour of England',
#          'alternateName': None,
#          'longAlternateName': None,
#          'unofficialName': None,
#          'year': 1977,
#          'typeId': 4,
#          'isTrophy': False,
#          'description': '',
#          'season': '1977',
#          'startDate': '1977-07-09T00:00:00.000Z',
#          'endDate': '1977-07-11T00:00:00.000Z',
#          'hasStandings': False,
#          'standingsType': 1,
#          'totalVideos': 0,
#          'gamePlayWatch': False},
#         'ground': {'id': 953,
#          'objectId': 56747,
#          'name': 'Arundel Castle Cricket Club Ground',
#          'smallName': 'Arundel',
#          'longName': 'Arundel Castle Cricket Club Ground',
#          'slug': 'arundel-castle-cricket-club-ground',
#          'location': '',
#          'image': {'id': 92273,
#           'objectId': 361414,
#           'slug': 'a-general-view-of-arundel',
#           'url': '/db/PICTURES/CMS/92200/92273.jpg',
#           'width': 500,
#           'height': 308,
#           'caption': 'A general view of Arundel',
#           'longCaption': 'A general view of Arundel, Sussex v Hampshire, Arundel, July 16, 2008',
#           'credit': 'Getty Images',
#           'photographer': None,
#           'peerUrls': None},
#          'town': {'id': 83,
#           'objectId': 56746,
#           'name': 'Arundel',
#           'area': '',
#           'timezone': 'Europe/London'},
#          'country': {'id': 1,
#           'objectId': 1,
#           'name': 'England',
#           'shortName': 'England',
#           'abbreviation': 'ENG',
#           'slug': 'england'}},
#         'teams': [{'team': {'id': 1022,
#            'objectId': 971,
#            'scribeId': 971,
#            'slug': 'england-under-19s-young-cricketers',
#            'name': 'England YC',
#            'longName': 'England Young Cricketers',
#            'abbreviation': 'EngYC',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313260.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313260,
#             'objectId': 1241719,
#             'slug': 'england-under-19s-young-cricketers-logo',
#             'url': '/db/PICTURES/CMS/313200/313260.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'England Under-19s (Young Cricketers) logo',
#             'longCaption': 'England Under-19s (Young Cricketers) logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': True,
#           'isLive': False,
#           'score': '245/4',
#           'scoreInfo': '45/45 ov',
#           'inningNumbers': [1],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None},
#          {'team': {'id': 284,
#            'objectId': 233,
#            'scribeId': 233,
#            'slug': 'australia-under-19s',
#            'name': 'Australia YC',
#            'longName': 'Australia Young Cricketers',
#            'abbreviation': 'AusYC',
#            'unofficialName': None,
#            'imageUrl': '/db/PICTURES/CMS/313200/313224.logo.png',
#            'isCountry': False,
#            'primaryColor': None,
#            'image': {'id': 313224,
#             'objectId': 1241683,
#             'slug': 'australia-under-19s-logo',
#             'url': '/db/PICTURES/CMS/313200/313224.logo.png',
#             'width': 500,
#             'height': 500,
#             'caption': 'Australia Under-19s logo',
#             'longCaption': 'Australia Under-19s logo',
#             'credit': None,
#             'photographer': None,
#             'peerUrls': None}},
#           'isHome': False,
#           'isLive': False,
#           'score': '213/7',
#           'scoreInfo': '45/45 ov, T:246',
#           'inningNumbers': [2],
#           'points': None,
#           'sidePlayers': None,
#           'sideBatsmen': None,
#           'sideFielders': None,
#           'captain': None,
#           'teamOdds': None}],
#         'dayType': 'SINGLE',
#         'format': 'ODI',
#         'previewStoryId': None,
#         'reportStoryId': None,
#         'liveBlogStoryId': None,
#         'fantasyPickStoryId': None,
#         'drawOdds': None,
#         'isSuperOver': False,
#         'isScheduledInningsComplete': True,
#         'hasSuperStats': False,
#         'totalGalleries': 0,
#         'totalImages': 0,
#         'totalVideos': 0,
#         'totalStories': 0,
#         'languages': [],
#         'generatedAt': '2023-09-13T23:08:26.352Z'},
#        'teamId': 284,
#        'battingText': '24',
#        'bowlingText': None,
#        'keepingText': None}]}]},
#   'stories': [],
#   'videos': [],
#   'images': [],
#   'supportInfo': {'teamRecentTeam': {'id': 8,
#     'objectId': 8,
#     'scribeId': 8,
#     'slug': 'sri-lanka',
#     'name': 'Sri Lanka',
#     'longName': 'Sri Lanka',
#     'abbreviation': 'SL',
#     'unofficialName': '',
#     'imageUrl': '/db/PICTURES/CMS/340000/340047.png',
#     'isCountry': True,
#     'primaryColor': '#203d89',
#     'image': {'id': 340047,
#      'objectId': 1316921,
#      'slug': 'sri-lanka-team-flag',
#      'url': '/db/PICTURES/CMS/340000/340047.png',
#      'width': 500,
#      'height': 500,
#      'caption': 'Sri Lanka team flag',
#      'longCaption': 'Sri Lanka team flag',
#      'credit': 'Google',
#      'photographer': None,
#      'peerUrls': None}},
#    'teamRecentPlayers': [{'id': 78229,
#      'objectId': 784367,
#      'name': 'KIC Asalanka',
#      'longName': 'Charith Asalanka',
#      'mobileName': 'Asalanka',
#      'indexName': 'Asalanka, KIC',
#      'battingName': 'KIC Asalanka',
#      'fieldingName': 'Asalanka',
#      'slug': 'charith-asalanka',
#      'imageUrl': '/db/PICTURES/CMS/348100/348128.4.jpg',
#      'dateOfBirth': {'year': 1997, 'month': 6, 'date': 29},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['ob'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['right-arm offbreak'],
#      'image': {'id': 348128,
#       'objectId': 1341438,
#       'slug': 'charith-asalanka-player-portrait',
#       'url': '/db/PICTURES/CMS/348100/348128.4.jpg',
#       'width': 160,
#       'height': 225,
#       'caption': 'Charith Asalanka, player portrait',
#       'longCaption': 'Charith Asalanka, player portrait',
#       'credit': 'ICC/Getty Images',
#       'photographer': 'Matt King',
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [10],
#      'playingRoles': ['batting allrounder'],
#      'headshotImage': {'id': 348599,
#       'objectId': 1342892,
#       'slug': 'charith-asalanka-player-page-headshot-cutout-2022',
#       'url': '/db/PICTURES/CMS/348500/348599.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Charith Asalanka, player page headshot cutout 2022',
#       'longCaption': 'Charith Asalanka, player page headshot cutout 2022',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/348500/348599.square.png'}}},
#     {'id': 62760,
#      'objectId': 465793,
#      'name': 'DM de Silva',
#      'longName': 'Dhananjaya de Silva',
#      'mobileName': 'Dhananjaya',
#      'indexName': 'de Silva, DM',
#      'battingName': 'DM de Silva',
#      'fieldingName': 'de Silva',
#      'slug': 'dhananjaya-de-silva',
#      'imageUrl': '/db/PICTURES/CMS/303800/303832.png',
#      'dateOfBirth': {'year': 1991, 'month': 9, 'date': 6},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['ob'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm offbreak'],
#      'image': {'id': 303832,
#       'objectId': 1222666,
#       'slug': 'dhananjaya-de-silva-portrait',
#       'url': '/db/PICTURES/CMS/303800/303832.png',
#       'width': 160,
#       'height': 201,
#       'caption': 'Dhananjaya de Silva portrait',
#       'longCaption': 'Dhananjaya de Silva, May 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [5],
#      'playingRoles': ['allrounder'],
#      'headshotImage': {'id': 319859,
#       'objectId': 1259931,
#       'slug': 'dhananjaya-de-silva-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/319800/319859.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Dhananjaya de Silva player page headshot cutout, 2021',
#       'longCaption': 'Dhananjaya de Silva player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/319800/319859.square.png'}}},
#     {'id': 78239,
#      'objectId': 784379,
#      'name': 'PWH de Silva',
#      'longName': 'Wanindu Hasaranga',
#      'mobileName': 'Hasaranga',
#      'indexName': 'de Silva, PWH',
#      'battingName': 'PWH de Silva',
#      'fieldingName': 'de Silva',
#      'slug': 'wanindu-hasaranga',
#      'imageUrl': '/db/PICTURES/CMS/294200/294296.jpg',
#      'dateOfBirth': {'year': 1997, 'month': 7, 'date': 29},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lb'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['legbreak'],
#      'image': {'id': 294296,
#       'objectId': 1199371,
#       'slug': 'wanindu-hasaranga',
#       'url': '/db/PICTURES/CMS/294200/294296.jpg',
#       'width': 160,
#       'height': 210,
#       'caption': 'Wanindu Hasaranga',
#       'longCaption': None,
#       'credit': 'Chaminda de Silva',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [5],
#      'playingRoles': ['allrounder'],
#      'headshotImage': {'id': 322946,
#       'objectId': 1266041,
#       'slug': 'wanindu-hasaranga-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/322900/322946.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Wanindu Hasaranga player page headshot cutout, 2021',
#       'longCaption': 'Wanindu Hasaranga player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/322900/322946.square.png'}}},
#     {'id': 48988,
#      'objectId': 227772,
#      'name': 'FDM Karunaratne',
#      'longName': 'Dimuth Karunaratne',
#      'mobileName': 'Dimuth Karunaratne',
#      'indexName': 'Karunaratne, FDM',
#      'battingName': 'FDM Karunaratne',
#      'fieldingName': 'Karunaratne',
#      'slug': 'dimuth-karunaratne',
#      'imageUrl': '/db/PICTURES/CMS/358800/358835.3.jpg',
#      'dateOfBirth': {'year': 1988, 'month': 4, 'date': 21},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['rm'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['right-arm medium'],
#      'image': {'id': 358835,
#       'objectId': 1371419,
#       'slug': 'dimuth-karunaratne-player-portrait',
#       'url': '/db/PICTURES/CMS/358800/358835.3.jpg',
#       'width': 160,
#       'height': 239,
#       'caption': 'Dimuth Karunaratne, player portrait',
#       'longCaption': 'Dimuth Karunaratne, player portrait',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [1],
#      'playingRoles': ['opening batter'],
#      'headshotImage': {'id': 358954,
#       'objectId': 1371807,
#       'slug': 'dimuth-karunaratne-player-page-headshot-cutout-2023',
#       'url': '/db/PICTURES/CMS/358900/358954.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Dimuth Karunaratne, player page headshot cutout 2023',
#       'longCaption': 'Dimuth Karunaratne, player page headshot cutout 2023',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/358900/358954.square.png'}}},
#     {'id': 78235,
#      'objectId': 784375,
#      'name': 'CBRLS Kumara',
#      'longName': 'Lahiru Kumara',
#      'mobileName': 'Lahiru Kumara',
#      'indexName': 'Kumara, CBRLS',
#      'battingName': 'CBRLS Kumara',
#      'fieldingName': 'Kumara',
#      'slug': 'lahiru-kumara',
#      'imageUrl': '/db/PICTURES/CMS/303800/303837.png',
#      'dateOfBirth': {'year': 1997, 'month': 2, 'date': 13},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['rf'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['right-arm fast'],
#      'image': {'id': 303837,
#       'objectId': 1222671,
#       'slug': 'lahiru-kumara-portrait',
#       'url': '/db/PICTURES/CMS/303800/303837.png',
#       'width': 160,
#       'height': 202,
#       'caption': 'Lahiru Kumara portrait',
#       'longCaption': 'Lahiru Kumara, May 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [4],
#      'playingRoles': ['bowler'],
#      'headshotImage': {'id': 322942,
#       'objectId': 1266037,
#       'slug': 'lahiru-kumara-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/322900/322942.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Lahiru Kumara player page headshot cutout, 2021',
#       'longCaption': 'Lahiru Kumara player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/322900/322942.square.png'}}},
#     {'id': 70888,
#      'objectId': 629074,
#      'name': 'BKG Mendis',
#      'longName': 'Kusal Mendis',
#      'mobileName': 'Mendis',
#      'indexName': 'Mendis, BKG',
#      'battingName': 'BKG Mendis',
#      'fieldingName': 'Mendis',
#      'slug': 'kusal-mendis',
#      'imageUrl': '/db/PICTURES/CMS/303800/303835.png',
#      'dateOfBirth': {'year': 1995, 'month': 2, 'date': 2},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lb'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['legbreak'],
#      'image': {'id': 303835,
#       'objectId': 1222669,
#       'slug': 'kusal-mendis-portrait',
#       'url': '/db/PICTURES/CMS/303800/303835.png',
#       'width': 160,
#       'height': 202,
#       'caption': 'Kusal Mendis portrait',
#       'longCaption': 'Kusal Mendis, May 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [7],
#      'playingRoles': ['wicketkeeper batter'],
#      'headshotImage': {'id': 319866,
#       'objectId': 1259938,
#       'slug': 'kusal-mendis-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/319800/319866.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Kusal Mendis player page headshot cutout, 2021',
#       'longCaption': 'Kusal Mendis player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/319800/319866.square.png'}}},
#     {'id': 93033,
#      'objectId': 1028655,
#      'name': 'P Nissanka',
#      'longName': 'Pathum Nissanka',
#      'mobileName': 'Nissanka',
#      'indexName': 'Nissanka, P',
#      'battingName': 'P Nissanka',
#      'fieldingName': 'Nissanka',
#      'slug': 'pathum-nissanka',
#      'imageUrl': '/db/PICTURES/CMS/318400/318435.jpg',
#      'dateOfBirth': {'year': 1998, 'month': 5, 'date': 18},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': [],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': [],
#      'image': {'id': 318435,
#       'objectId': 1256641,
#       'slug': 'pathum-nissanka-portrait',
#       'url': '/db/PICTURES/CMS/318400/318435.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'Pathum Nissanka portrait',
#       'longCaption': 'Pathum Nissanka portrait, Antigua and Barbuda, March 12, 2021',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [2],
#      'playingRoles': ['top-order batter'],
#      'headshotImage': {'id': 323070,
#       'objectId': 1266243,
#       'slug': 'pathum-nissaka-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/323000/323070.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Pathum Nissaka player page headshot cutout, 2021',
#       'longCaption': 'Pathum Nissaka player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/323000/323070.square.png'}}},
#     {'id': 64698,
#      'objectId': 499594,
#      'name': 'CAK Rajitha',
#      'longName': 'Kasun Rajitha',
#      'mobileName': 'Rajitha',
#      'indexName': 'Rajitha, CAK',
#      'battingName': 'CAK Rajitha',
#      'fieldingName': 'Rajitha',
#      'slug': 'kasun-rajitha',
#      'imageUrl': '/db/PICTURES/CMS/303800/303833.png',
#      'dateOfBirth': {'year': 1993, 'month': 6, 'date': 1},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rmf'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium-fast'],
#      'image': {'id': 303833,
#       'objectId': 1222667,
#       'slug': 'kasun-rajitha-portrait',
#       'url': '/db/PICTURES/CMS/303800/303833.png',
#       'width': 160,
#       'height': 202,
#       'caption': 'Kasun Rajitha portrait',
#       'longCaption': 'Kasun Rajitha, May 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 8,
#      'playerRoleTypeIds': [4],
#      'playingRoles': ['bowler'],
#      'headshotImage': {'id': 322957,
#       'objectId': 1266053,
#       'slug': 'kasun-rajitha-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/322900/322957.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Kasun Rajitha player page headshot cutout, 2021',
#       'longCaption': 'Kasun Rajitha player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/322900/322957.square.png'}}},
#     {'id': 61690,
#      'objectId': 437316,
#      'name': 'MD Shanaka',
#      'longName': 'Dasun Shanaka',
#      'mobileName': 'Shanaka',
#      'indexName': 'Shanaka, MD',
#      'battingName': 'MD Shanaka',
#      'fieldingName': 'Shanaka',
#      'slug': 'dasun-shanaka',
#      'imageUrl': '/db/PICTURES/CMS/327900/327999.7.jpg',
#      'dateOfBirth': {'year': 1991, 'month': 9, 'date': 9},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rm'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium'],
# ...
#       'caption': 'Maheesh Theekshana, player page headshot cutout 2022',
#       'longCaption': 'Maheesh Theekshana, player page headshot cutout 2022',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/347800/347825.square.png'}}}],
#    'teamPopularPlayers': [{'id': 104403,
#      'objectId': 1170471,
#      'name': 'T Sangha',
#      'longName': 'Tanveer Sangha',
#      'mobileName': 'T Sangha',
#      'indexName': 'Sangha, T',
#      'battingName': 'T Sangha',
#      'fieldingName': 'Sangha',
#      'slug': 'tanveer-sangha',
#      'imageUrl': None,
#      'dateOfBirth': {'year': 2001, 'month': 11, 'date': 26},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lb'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['legbreak'],
#      'image': None,
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [4],
#      'playingRoles': ['bowler'],
#      'headshotImage': None},
#     {'id': 48739,
#      'objectId': 219889,
#      'name': 'DA Warner',
#      'longName': 'David Warner',
#      'mobileName': 'Warner',
#      'indexName': 'Warner, DA',
#      'battingName': 'DA Warner',
#      'fieldingName': 'Warner',
#      'slug': 'david-warner',
#      'imageUrl': '/db/PICTURES/CMS/263500/263541.1.jpg',
#      'dateOfBirth': {'year': 1986, 'month': 10, 'date': 27},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['lb'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['legbreak'],
#      'image': {'id': 263541,
#       'objectId': 1099532,
#       'slug': 'david-warner',
#       'url': '/db/PICTURES/CMS/263500/263541.1.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'David Warner',
#       'longCaption': 'David Warner',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [1],
#      'playingRoles': ['opening batter'],
#      'headshotImage': {'id': 316589,
#       'objectId': 1251218,
#       'slug': 'da-warner-headshot',
#       'url': '/db/PICTURES/CMS/316500/316589.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'DA Warner headshot',
#       'longCaption': 'DA Warner headshot',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None, 'WIDE': None, 'SQUARE': None}}},
#     {'id': 66190,
#      'objectId': 530011,
#      'name': 'TM Head',
#      'longName': 'Travis Head',
#      'mobileName': 'Head',
#      'indexName': 'Head, TM',
#      'battingName': 'TM Head',
#      'fieldingName': 'Head',
#      'slug': 'travis-head',
#      'imageUrl': '/db/PICTURES/CMS/263500/263525.1.jpg',
#      'dateOfBirth': {'year': 1993, 'month': 12, 'date': 29},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['lhb'],
#      'bowlingStyles': ['ob'],
#      'longBattingStyles': ['left-hand bat'],
#      'longBowlingStyles': ['right-arm offbreak'],
#      'image': {'id': 263525,
#       'objectId': 1099504,
#       'slug': 'travis-head',
#       'url': '/db/PICTURES/CMS/263500/263525.1.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'Travis Head',
#       'longCaption': 'Travis Head',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [3],
#      'playingRoles': ['middle-order batter'],
#      'headshotImage': {'id': 321584,
#       'objectId': 1263516,
#       'slug': 'travis-head-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/321500/321584.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Travis Head player page headshot cutout, 2021',
#       'longCaption': 'Travis Head player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/321500/321584.square.png'}}},
#     {'id': 78285,
#      'objectId': 787987,
#      'name': 'M Labuschagne',
#      'longName': 'Marnus Labuschagne',
#      'mobileName': 'Labuschagne',
#      'indexName': 'Labuschagne, M',
#      'battingName': 'M Labuschagne',
#      'fieldingName': 'Labuschagne',
#      'slug': 'marnus-labuschagne',
#      'imageUrl': '/db/PICTURES/CMS/281100/281119.1.jpg',
#      'dateOfBirth': {'year': 1994, 'month': 6, 'date': 22},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lb'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['legbreak'],
#      'image': {'id': 281119,
#       'objectId': 1162108,
#       'slug': 'marnus-labuschagne-portrait',
#       'url': '/db/PICTURES/CMS/281100/281119.1.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'Marnus Labuschagne portrait',
#       'longCaption': 'Marnus Labuschagne portrait, October 2018',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [10],
#      'playingRoles': ['batting allrounder'],
#      'headshotImage': {'id': 321585,
#       'objectId': 1263517,
#       'slug': 'marnus-labuschagne-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/321500/321585.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Marnus Labuschagne player page headshot cutout, 2021',
#       'longCaption': 'Marnus Labuschagne player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/321500/321585.square.png'}}},
#     {'id': 83439,
#      'objectId': 892749,
#      'name': 'TH David',
#      'longName': 'Tim David',
#      'mobileName': 'David',
#      'indexName': 'David, TH',
#      'battingName': 'TH David',
#      'fieldingName': 'David',
#      'slug': 'tim-david',
#      'imageUrl': '/db/PICTURES/CMS/313600/313639.1.jpg',
#      'dateOfBirth': {'year': 1996, 'month': 3, 'date': 16},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['ob'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm offbreak'],
#      'image': {'id': 313639,
#       'objectId': 1243165,
#       'slug': 'tim-david-player-portrait',
#       'url': '/db/PICTURES/CMS/313600/313639.1.jpg',
#       'width': 160,
#       'height': 200,
#       'caption': 'Tim David player portrait',
#       'longCaption': 'Tim David player portrait',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [3],
#      'playingRoles': ['middle-order batter'],
#      'headshotImage': {'id': 340305,
#       'objectId': 1318025,
#       'slug': 'tim-david-player-page-headshot-cutout-2022',
#       'url': '/db/PICTURES/CMS/340300/340305.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Tim David, player page headshot cutout 2022',
#       'longCaption': 'Tim David, player page headshot cutout 2022',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/340300/340305.square.png'}}},
#     {'id': 80817,
#      'objectId': 826915,
#      'name': 'NT Ellis',
#      'longName': 'Nathan Ellis',
#      'mobileName': 'Ellis',
#      'indexName': 'Ellis, NT',
#      'battingName': 'NT Ellis',
#      'fieldingName': 'Ellis',
#      'slug': 'nathan-ellis',
#      'imageUrl': '/db/PICTURES/CMS/327000/327014.4.jpg',
#      'dateOfBirth': {'year': 1994, 'month': 9, 'date': 22},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rfm'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm fast-medium'],
#      'image': {'id': 327014,
#       'objectId': 1276809,
#       'slug': 'nathan-ellis-player-portrait',
#       'url': '/db/PICTURES/CMS/327000/327014.4.jpg',
#       'width': 160,
#       'height': 254,
#       'caption': 'Nathan Ellis, player portrait',
#       'longCaption': 'Nathan Ellis, player portrait',
#       'credit': 'AFP/Getty Images',
#       'photographer': 'Randy Brooks',
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [4],
#      'playingRoles': ['bowler'],
#      'headshotImage': {'id': 329711,
#       'objectId': 1286643,
#       'slug': 'nathan-ellis-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/329700/329711.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Nathan Ellis player page headshot cutout 2021',
#       'longCaption': 'Nathan Ellis player page headshot cutout 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/329700/329711.square.png'}}},
#     {'id': 50771,
#      'objectId': 272450,
#      'name': 'MR Marsh',
#      'longName': 'Mitchell Marsh',
#      'mobileName': 'Marsh',
#      'indexName': 'Marsh, MR',
#      'battingName': 'MR Marsh',
#      'fieldingName': 'Marsh',
#      'slug': 'mitchell-marsh',
#      'imageUrl': '/db/PICTURES/CMS/356700/356780.1.png',
#      'dateOfBirth': {'year': 1991, 'month': 10, 'date': 20},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rm'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium'],
#      'image': {'id': 356780,
#       'objectId': 1364982,
#       'slug': 'mitchell-marsh-player-portrait',
#       'url': '/db/PICTURES/CMS/356700/356780.1.png',
#       'width': 160,
#       'height': 187,
#       'caption': 'Mitchell Marsh player portrait',
#       'longCaption': 'Mitchell Marsh player portrait',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [5],
#      'playingRoles': ['allrounder'],
#      'headshotImage': {'id': 316612,
#       'objectId': 1251244,
#       'slug': 'mr-marsh-headshot',
#       'url': '/db/PICTURES/CMS/316600/316612.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'MR Marsh headshot',
#       'longCaption': 'MR Marsh headshot',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None, 'WIDE': None, 'SQUARE': None}}},
#     {'id': 50281,
#      'objectId': 267192,
#      'name': 'SPD Smith',
#      'longName': 'Steven Smith',
#      'mobileName': 'Smith',
#      'indexName': 'Smith, SPD',
#      'battingName': 'SPD Smith',
#      'fieldingName': 'Smith',
#      'slug': 'steven-smith',
#      'imageUrl': '/db/PICTURES/CMS/309500/309571.1.jpg',
#      'dateOfBirth': {'year': 1989, 'month': 6, 'date': 2},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['lbg'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['legbreak googly'],
#      'image': {'id': 309571,
#       'objectId': 1233596,
#       'slug': 'steven-smith-player-portrait',
#       'url': '/db/PICTURES/CMS/309500/309571.1.jpg',
#       'width': 160,
#       'height': 198,
#       'caption': 'Steven Smith player portrait',
#       'longCaption': 'Steven Smith player portrait',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [3],
#      'playingRoles': ['middle-order batter'],
#      'headshotImage': {'id': 316609,
#       'objectId': 1251241,
#       'slug': 'spd-smith-headshot',
#       'url': '/db/PICTURES/CMS/316600/316609.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'SPD Smith headshot',
#       'longCaption': 'SPD Smith headshot',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None, 'WIDE': None, 'SQUARE': None}}},
#     {'id': 59610,
#      'objectId': 398666,
#      'name': 'SA Abbott',
#      'longName': 'Sean Abbott',
#      'mobileName': 'Abbott',
#      'indexName': 'Abbott, SA',
#      'battingName': 'SA Abbott',
#      'fieldingName': 'Abbott',
#      'slug': 'sean-abbott',
#      'imageUrl': '/db/PICTURES/CMS/312100/312161.png',
#      'dateOfBirth': {'year': 1992, 'month': 2, 'date': 29},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rfm'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm fast-medium'],
#      'image': {'id': 312161,
#       'objectId': 1239220,
#       'slug': 'sean-abbott-portrait',
#       'url': '/db/PICTURES/CMS/312100/312161.png',
#       'width': 160,
#       'height': 202,
#       'caption': 'Sean Abbott portrait',
#       'longCaption': 'Sean Abbott portrait, November 2020',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [11],
#      'playingRoles': ['bowling allrounder'],
#      'headshotImage': {'id': 321601,
#       'objectId': 1263535,
#       'slug': 'sean-abbott-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/321600/321601.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Sean Abbott player page headshot cutout, 2021',
#       'longCaption': 'Sean Abbott player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/321600/321601.square.png'}}},
#     {'id': 2230,
#      'objectId': 7133,
#      'name': 'RT Ponting',
#      'longName': 'Ricky Ponting',
#      'mobileName': 'Ponting',
#      'indexName': 'Ponting, RT',
#      'battingName': 'RT Ponting',
#      'fieldingName': 'Ponting',
#      'slug': 'ricky-ponting',
#      'imageUrl': '/db/PICTURES/CMS/202600/202613.1.jpg',
#      'dateOfBirth': {'year': 1974, 'month': 12, 'date': 19},
#      'dateOfDeath': None,
#      'gender': 'M',
#      'battingStyles': ['rhb'],
#      'bowlingStyles': ['rm'],
#      'longBattingStyles': ['right-hand bat'],
#      'longBowlingStyles': ['right-arm medium'],
#      'image': {'id': 202613,
#       'objectId': 817155,
#       'slug': 'ricky-ponting-player-pic',
#       'url': '/db/PICTURES/CMS/202600/202613.1.jpg',
#       'width': 160,
#       'height': 192,
#       'caption': 'Ricky Ponting player pic',
#       'longCaption': 'Ricky Ponting player profile pic',
#       'credit': 'Getty Images',
#       'photographer': None,
#       'peerUrls': None},
#      'countryTeamId': 2,
#      'playerRoleTypeIds': [2],
#      'playingRoles': ['top-order batter'],
#      'headshotImage': {'id': 319711,
#       'objectId': 1259710,
#       'slug': 'ricky-ponting-player-page-headshot-cutout-2021',
#       'url': '/db/PICTURES/CMS/319700/319711.png',
#       'width': 600,
#       'height': 436,
#       'caption': 'Ricky Ponting player page headshot cutout, 2021',
#       'longCaption': 'Ricky Ponting player page headshot cutout, 2021',
#       'credit': None,
#       'photographer': None,
#       'peerUrls': {'FILM': None,
#        'WIDE': None,
#        'SQUARE': '/db/PICTURES/CMS/319700/319711.square.png'}}}],
#    'matchClassMetas': [{'id': 15,
#      'type': 'i',
#      'name': 'Youth One-Day Internationals'},
#     {'id': 4, 'type': 'g', 'name': 'First-class'}],
#    'recordClassMetas': [{'id': 4,
#      'type': 'g',
#      'name': 'FC',
#      'longName': 'First-class matches',
#      'multipleClass': 0,
#      'slug': 'first-class-matches'},
#     {'id': 21,
#      'type': 'i',
#      'name': 'Youth ODI',
#      'longName': 'Under-19s Youth One-Day Internationals',
#      'multipleClass': 0,
#      'slug': 'under-19s-youth-one-day-internationals'}],
#    'overallStats': [],
#    'teamFormatCapCounts': {'1': 466,
#     '2': 241,
#     '3': 107,
#     '8': 183,
#     '9': 149,
#     '10': 60,
#     '14': 320,
#     '15': 482,
#     '16': 11},
#    'teamContractedPlayerCount': 20,
#    'teamMatchClassMetas': [{'id': 1, 'type': 'i', 'name': 'Tests'},
#     {'id': 2, 'type': 'i', 'name': 'One-Day Internationals'},
#     {'id': 3, 'type': 'i', 'name': 'Twenty20 Internationals'},
#     {'id': 8, 'type': 'i', 'name': "Women's Tests"},
#     {'id': 9, 'type': 'i', 'name': "Women's One-Day Internationals"},
#     {'id': 10, 'type': 'i', 'name': "Women's Twenty20 Internationals"},
#     {'id': 6, 'type': 'g', 'name': 'Twenty20'},
#     {'id': 17, 'type': 'g', 'name': "Women's Twenty20"}]}}}

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
